# %%
FIRE INCIDENTS

# %%
import pandas as pd

# Load dataset
fire_data = pd.read_csv("fireIncidents.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /ihome/crc/install/jupyterhub/hub4.0.2/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Neighborhood'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 10
#       7 neighborhood_name = "Allentown"
# ...

# %%
POLICE BLOTTER
# Out:
#   Cell In[8], line 1
#     POLICE BLOTTER
#            ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# Load dataset
police_data = pd.read_csv("policeBlotter.csv")
# Out:
# /scratch/slurm-11145/ipykernel_117110/572905499.py:4: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   police_data = pd.read_csv("policeBlotter.csv")

# %%
PUBLIC PARKS

# %%
import pandas as pd

# Load dataset
park_data = pd.read_csv("publicParks.csv")
